# %%
import angr
import networkx as nx

# %%
# class binary_controler:
#     def __init__(self, bin_location, output_location, output_name):
#         self.bin_location = bin_location
#         self.output_location = output_location
#         self.output_name = output_name
#         self.cfglist = []
        
#     def handle_CFG(self):
#         self.project = angr.Project(self.bin_location, load_options={'auto_load_libs': False})
#         self.cfg = self.project.analyses.CFGFast()
        
#     def derivate_fun_cfg(self):
#         i = 0
#         for function_addr, function in self.cfg.kb.functions.items():
#             func_cfg = self.project.analyses.CFGFast(force_complete_scan=False, start_at_entry=function_addr, function_prologues=True)
#             self.cfglist.append(func_cfg)
#             print(function_addr,function)
#             i = i + 1
#             if (i > 4):
#                 break

# %%
# bin_file = binary_controler('/usr/local/binutils/bin/addr2line', '~/PycharmProjects/prakProject/output_CFG', "CFG")

# %%
# bin_file.handle_CFG()
# Out:
# WARNING  | 2024-05-13 09:12:40,053 | cle.backends.tls.tls_object | The provided object has an invalid tls_data_size. Skip TLS loading.
# WARNING  | 2024-05-13 09:12:47,704 | angr.analyses.propagator.engine_vex.SimEnginePropagatorVEX | Unsupported Binop Iop_64HLto128.
# ERROR    | 2024-05-13 09:13:33,439 | angr.analyses.propagator.engine_vex.SimEnginePropagatorVEX | Unsupported statement type CAS.
# WARNING  | 2024-05-13 09:13:33,439 | angr.analyses.propagator.engine_vex.SimEnginePropagatorVEX | Unsupported Binop Iop_CasCmpNE8.

# %%
# bin_file.derivate_fun_cfg()

# %%
# for cfg in bin_file.cfglist:
#     plot_cfg(cfg, "ais3_cfg", asminst=True, remove_imports=True, remove_path_terminator=True)

# %%
# project = angr.Project('/usr/local/binutils/bin/addr2line', load_options={'auto_load_libs': False})
# cfg = project.analyses.CFGFast()
# for func_addr in cfg.kb.functions:
#     func = cfg.kb.functions[func_addr]
#     print(func.name)

# %%
# for func_addr in cfg.kb.functions:
#     func = cfg.kb.functions[func_addr]
#     if (func.name == "mkstemps")
#     print(func.name)

# %%
# project = angr.Project('/usr/local/binutils/bin/addr2line', load_options={'auto_load_libs': False})
# cfg = project.analyses.CFGFast()
# function_cfgs = {}

# for func_addr in cfg.kb.functions:
#     func = cfg.kb.functions[func_addr]
#     ## 添加对function用法的判定，备注只有相同的元文件具有相同函数名的函数才能才一起进行测试
#     ## 如果node的数量小于3,则不对该函数进行添加
#     length = 0
#     for _ in func.blocks:
#         length = length +1
#     if (func.name.startswith('sub_') or length <= 3):
#         continue
        
#     G = nx.DiGraph()
    
#     blocks = list(func.blocks)
    
#     for block in blocks:
#         G.add_node(block.addr, block = block)

#     for block in blocks:
#         command = block.disassembly
#         instr = command.insns[-1]
#         try :
#             address = int(instr.op_str,16)
#         except ValueError:
#             continue
#         print(len(successors))
#         for succ in successors:
#             if succ.addr in G:
#                 G.add_edge(block.addr, succ.addr)
                
#     function_cfgs[func.name] = G

# %%
project = angr.Project('/usr/local/binutils/bin/addr2line', load_options={'auto_load_libs': False})
cfg = project.analyses.CFGFast()
function_cfgs = {}
# Out:
# WARNING  | 2024-05-20 20:37:40,833 | cle.backends.tls.tls_object | The provided object has an invalid tls_data_size. Skip TLS loading.

# %%
for func_addr in cfg.kb.functions:
    func = cfg.kb.functions[func_addr]
    ## 添加对function用法的判定，备注只有相同的元文件具有相同函数名的函数才能才一起进行测试
    ## 如果node的数量小于3,则不对该函数进行添加
    length = 0
#     for node in func.nodes:
#         print(type(node))
#     print(type(func))
    for _ in func.blocks:
        length = length +1
    if (func.name.startswith('sub_') or length <= 3 or func.is_syscall):
        continue
        
    G = nx.DiGraph()
    
    blocks = list(func.blocks)
    
    for block in blocks:
        G.add_node(block.addr, block = block)
#         print(type(block.addr))

    for block in blocks:
        node = cfg.get_any_node(block.addr)
        successors = cfg.get_successors(node)
#         print(len(successors))
        for succ in successors:
            if succ.addr in G:
                G.add_edge(block.addr, succ.addr)
                
    function_cfgs[func.name] = G

# %%
# data_sections = [section for section in project.loader.main_object.sections if section.is_readable and section.name in ['.data', '.rodata']]

# %%
# print(type(data_sections[0]))
# Out:
# <class 'cle.backends.elf.regions.ELFSection'>

# %%
# node = cfg.get_any_node(int("0x433730",16))
# print(type(node))
# print(node.successors)
# for i in node.successors:
#     print(hex(i.addr))
#     print(type(i.addr))  ## test node

# %%
# for name in function_cfgs:
#     print(name)  ##show function node

# %%
# i = 1
# for name in function_cfgs:
#     i = i + 1
#     print(function_cfgs[name].number_of_nodes())
#     if(i > 30):
#         break

# %%
def count_string_constants(block):
    constants = 0
#     print(type(block))
    for insn in block.capstone.insns:
#         print(type(insn))
        for operand in insn.operands:
#             print(operand.value)
#            print(type(operand))
            if operand.type == 2:  # memory.data
                mem_addr = operand.mem.disp
                try:
                    # 尝试将值解释为字符串
                    string = project.loader.memory.load(mem_addr, 20).tobytes()
                    if is_printable_string(string):
                        constants = constants + 1
                except:
                    continue
    return constants

# %%
def count_num_constants(block):
    numeric_constants = 0
    for insn in block.capstone.insns:
        for operand in insn.operands:
            if operand.type == 1:  # Immediate value
                numeric_constants += 1
    return numeric_constants

# %%
def count_transfer(block):
    transfer_commands = {'jmp', 'je', 'jne', 'jg', 'jge', 'jl', 'jle','ja', 'jae', 'jb', 'jbe',
                        'loop', 'loope', 'loopne','jo', 'jno', 'js', 'jns','jp', 'jnp'}
    transfers = 0
    for insn in block.capstone.insns:
        if insn.mnemonic in transfer_commands:
            transfers+=1
    return transfers

# %%
def count_calls(block):
    calls = 0
    for insn in block.capstone.insns:
        if insn.mnemonic == 'call':
            calls+=1
    return calls

# %%
def count_instructions(block):
    return block.size

# %%
def count_arithmetic(block):
    arithmetic_commands = { ## only include the normalest command
        'add', 'sub', 'mul', 'imul', 'div', 'idiv','inc', 'dec', 'neg', 'adc', 'sbb'
    }
    arithmetics = 0
    for insn in block.capstone.insns:
        if insn.mnemonic in arithmetic_commands:
            arithmetics += 1
    
    return arithmetics

# %%
def count_offspring(block_addr, cfg_graph):
    visited_node = set()
    offsprings = 0
    stack = [block_addr]
    while stack:
        position = stack.pop()
        if position not in visited_node:
            visited_node.add(position)
            for successor in cfg_graph.successors(position):
                if successor not in visited_node:
                    stack.append(successor)
                    offsprings += 1
    return offsprings

# %%
def refin(acfg_graph):
    new_acfg = nx.DiGraph()
    for block_addr in acfg_graph.nodes:
        new_acfg.add_node(tuple(acfg_graph.nodes[block_addr]['block_attr']))
        
    for block_addr_1,block_addr_2 in acfg_graph.edges:
        new_acfg.add_edge(tuple(acfg_graph.nodes[block_addr_1]['block_attr']),tuple(acfg_graph.nodes[block_addr_2]['block_attr']))
    return new_acfg

# %%
## 将提取出的CFG变成ACFG
## 依据论文提取的block attribution
## 
def cfg_to_acfg(cfg_graph):
    acfg_graph = nx.DiGraph()
    for block_addr in cfg_graph.nodes:
#         print(type(block))
        block = cfg_graph.nodes[block_addr]['block']
        block_attr = []
        block_attr.append(count_string_constants(block))
        block_attr.append(count_num_constants(block))
        block_attr.append(count_transfer(block))
        block_attr.append(count_calls(block))
        block_attr.append(count_instructions(block))
        block_attr.append(count_arithmetic(block))
        block_attr.append(count_offspring(block_addr, cfg_graph))
        acfg_graph.add_node(block_addr, block_attr = block_attr)
    for u,v in cfg_graph.edges:
        acfg_graph.add_edge(u,v)
    blocks_between = nx.betweenness_centrality(cfg_graph)
    for block_addr, centrality in blocks_between.items():
        acfg_graph.nodes[block_addr]['block_attr'].append(centrality)
#         print(acfg_graph.nodes[block_addr]['block_attr'])
        
    refin_acg = refin(acfg_graph)
#     print(refin_acg)
    return refin_acg

# %%
graph_list = []
name_list = []

for name in function_cfgs:
    cfg_graph = function_cfgs[name]
#     print(type(list(cfg_graph.nodes)[0]))
    acfg_graph = cfg_to_acfg(cfg_graph)  ##将cfg变成acfg的运用
    graph_list.append(acfg_graph)
    name_list.append(name)

# %%
import pickle

with open("./graphs.pkl", "wb") as f:
    pickle.dump(graph_list, f)
    
with open("./names.pkl","wb") as f:
    pickle.dump(name_list, f)

# %%
print(name_list)
# Out:
# ['main', 'deregister_tm_clones', 'register_tm_clones', '__do_global_dtors_aux', 'usage', 'find_address_in_section', 'template_in_dir', 'endian_string', 'bfd_nonfatal', 'do_display_target', 'report', 'fatal', 'non_fatal', 'bfd_xalloc', 'set_default_bfd_target', 'list_matching_formats', 'list_supported_targets', 'list_supported_architectures', 'display_info', 'print_arelt_descr', 'make_tempname', 'make_tempdir', 'parse_vma', 'get_file_size', 'bfd_get_archive_filename', 'bfd_nonfatal_message', 'is_valid_archive_path', 'print_version', 'mode_string', 'bfd_default_scan', 'bfd_arch_default_fill', 'bfd_default_compatible', 'bfd_scan_arch', 'bfd_arch_list', 'bfd_arch_get_compatible', 'bfd_default_set_arch_mach', 'bfd_lookup_arch', 'bfd_printable_arch_mach', 'bfd_octets_per_byte', 'bfd_arch_mach_octets_per_byte', 'err_sprintf', 'bfd_asprintf', 'bfd_errmsg', 'bfd_perror', '_bfd_error_handler', 'bfd_thread_init', 'bfd_lock', 'bfd_unlock', 'bfd_get_reloc_upper_bound', 'bfd_canonicalize_reloc', 'bfd_set_file_flags', '_bfd_abort', 'bfd_set_input_error', '_bfd_doprnt_scan', '_bfd_doprnt', 'error_handler_fprintf', 'error_handler_sprintf', 'bfd_get_arch_size', 'bfd_get_sign_extend_vma', 'bfd_get_gp_size', 'bfd_set_gp_size', '_bfd_get_gp_value', '_bfd_set_gp_value', 'bfd_set_gp_value', 'bfd_record_phdr', 'bfd_sprintf_vma', 'bfd_fprintf_vma', 'bfd_alt_mach_code', 'bfd_emul_get_maxpagesize', 'bfd_emul_get_commonpagesize', 'bfd_demangle', 'print_warnmsg', 'bfd_preserve_restore', 'bfd_check_format_matches', 'bfd_set_format', 'bfd_format_string', 'bfd_hash_table_init_n', 'bfd_hash_insert', 'bfd_hash_lookup', 'bfd_hash_rename', 'bfd_hash_replace', 'bfd_hash_allocate', 'strtab_hash_newfunc', 'bfd_hash_newfunc', 'bfd_hash_traverse', 'bfd_hash_set_default_size', '_bfd_stringtab_init', '_bfd_xcoff_stringtab_init', '_bfd_stringtab_add', '_bfd_stringtab_emit', 'bfd_malloc', 'bfd_realloc', 'bfd_realloc_or_free', 'bfd_zmalloc', 'bfd_alloc', 'bfd_zalloc', 'bfd_write_bigendian_4byte_int', 'bfd_put_bits', 'bfd_get_bits', '_bfd_generic_get_section_contents', '_bfd_generic_set_section_contents', 'bfd_log2', '_bfd_read_unsigned_leb128', '_bfd_safe_read_leb128', '_bfd_read_signed_leb128', '_bfd_write_unsigned_leb128', 'opncls_bseek', 'opncls_bread', 'opncls_bstat', '_bfd_delete_bfd', 'separate_alt_debug_file_exists', 'bfd_get_debug_link_info_1', 'find_separate_debug_file', 'get_build_id', 'get_build_id_name', 'separate_debug_file_exists', '_bfd_new_bfd', '_bfd_new_bfd_contained_in', '_bfd_free_cached_info', 'bfd_elf_bfd_from_remote_memory', 'bfd_close_all_done', 'bfd_close', 'bfd_make_writable', 'bfd_make_readable', 'bfd_calc_gnu_debuglink_crc32', 'bfd_get_alt_debug_link_info', 'get_alt_debug_link_info_shim', 'bfd_follow_gnu_debuglink', 'bfd_create_gnu_debuglink_section', 'bfd_fill_in_gnu_debuglink_section', 'bfd_follow_build_id_debuglink', 'bfd_set_filename', 'bfd_fopen', 'check_build_id_file', 'bfd_fdopenr', 'bfd_fdopenw', 'bfd_openstreamr', 'bfd_openr_iovec', 'bfd_openw', 'bfd_create', 'bfd_section_init', 'bfd_section_hash_newfunc', '_bfd_generic_new_section_hook', 'bfd_get_section_by_name', 'bfd_get_next_section_by_name', 'bfd_get_linker_section', 'bfd_get_section_by_name_if', 'bfd_get_unique_section_name', 'bfd_make_section_old_way', 'bfd_make_section_anyway_with_flags', 'bfd_make_section_with_flags', 'bfd_map_over_sections', 'bfd_sections_find_if', 'bfd_set_section_size', 'bfd_set_section_contents', 'bfd_get_section_contents', '_bfd_section_size_insane', 'find_target', '_bfd_find_arch_match.part.0', '_bfd_per_xvec_warn', 'bfd_set_default_target', 'bfd_find_target', 'bfd_get_target_info', 'bfd_target_list', 'bfd_iterate_over_targets', 'bfd_flavour_name', 'mangle_name', 'binary_canonicalize_symtab', 'binary_get_section_contents', 'binary_object_p', 'binary_set_section_contents', 'ihex_mkobject', 'ihex_write_record', 'ihex_write_object_contents', 'ihex_set_section_contents', 'ihex_bad_byte', 'ihex_get_section_contents', 'ihex_object_p', 'srec_canonicalize_symtab ...

# %%
print(graph_list)
# Out:
# [<networkx.classes.digraph.DiGraph object at 0x7871a06bd390>, <networkx.classes.digraph.DiGraph object at 0x787198627590>, <networkx.classes.digraph.DiGraph object at 0x787198569550>, <networkx.classes.digraph.DiGraph object at 0x787198626590>, <networkx.classes.digraph.DiGraph object at 0x78719856bd10>, <networkx.classes.digraph.DiGraph object at 0x787196ecb9d0>, <networkx.classes.digraph.DiGraph object at 0x787198569d10>, <networkx.classes.digraph.DiGraph object at 0x787196ed8b90>, <networkx.classes.digraph.DiGraph object at 0x787196ed92d0>, <networkx.classes.digraph.DiGraph object at 0x7871984f44d0>, <networkx.classes.digraph.DiGraph object at 0x787198629390>, <networkx.classes.digraph.DiGraph object at 0x787196eb81d0>, <networkx.classes.digraph.DiGraph object at 0x78719862aa10>, <networkx.classes.digraph.DiGraph object at 0x787196edb750>, <networkx.classes.digraph.DiGraph object at 0x787196ecac50>, <networkx.classes.digraph.DiGraph object at 0x78719856a910>, <networkx.classes.digraph.DiGraph object at 0x7871a04bdf50>, <networkx.classes.digraph.DiGraph object at 0x7871970e1f10>, <networkx.classes.digraph.DiGraph object at 0x7871985c44d0>, <networkx.classes.digraph.DiGraph object at 0x787197087b50>, <networkx.classes.digraph.DiGraph object at 0x787198a2fdd0>, <networkx.classes.digraph.DiGraph object at 0x7871986013d0>, <networkx.classes.digraph.DiGraph object at 0x787198a2f890>, <networkx.classes.digraph.DiGraph object at 0x787198a2cf50>, <networkx.classes.digraph.DiGraph object at 0x7871989a29d0>, <networkx.classes.digraph.DiGraph object at 0x7871989a39d0>, <networkx.classes.digraph.DiGraph object at 0x787198f54d90>, <networkx.classes.digraph.DiGraph object at 0x787198f54310>, <networkx.classes.digraph.DiGraph object at 0x7871989a3450>, <networkx.classes.digraph.DiGraph object at 0x787196edb010>, <networkx.classes.digraph.DiGraph object at 0x7871a0775550>, <networkx.classes.digraph.DiGraph object at 0x787198a02c10>, <networkx.classes.digraph.DiGraph object at 0x7871986024d0>, <networkx.classes.digraph.DiGraph object at 0x787198a03890>, <networkx.classes.digraph.DiGraph object at 0x7871984c9290>, <networkx.classes.digraph.DiGraph object at 0x787198a60ed0>, <networkx.classes.digraph.DiGraph object at 0x787198a00a50>, <networkx.classes.digraph.DiGraph object at 0x787198a5f1d0>, <networkx.classes.digraph.DiGraph object at 0x787198a5ea90>, <networkx.classes.digraph.DiGraph object at 0x787198a30a50>, <networkx.classes.digraph.DiGraph object at 0x787198d83850>, <networkx.classes.digraph.DiGraph object at 0x787198d82050>, <networkx.classes.digraph.DiGraph object at 0x787198a30f50>, <networkx.classes.digraph.DiGraph object at 0x787198a311d0>, <networkx.classes.digraph.DiGraph object at 0x787198a5d010>, <networkx.classes.digraph.DiGraph object at 0x787198a5ff90>, <networkx.classes.digraph.DiGraph object at 0x787198a01650>, <networkx.classes.digraph.DiGraph object at 0x787198a631d0>, <networkx.classes.digraph.DiGraph object at 0x7871989fad50>, <networkx.classes.digraph.DiGraph object at 0x787198a69d90>, <networkx.classes.digraph.DiGraph object at 0x7871989fa2d0>, <networkx.classes.digraph.DiGraph object at 0x7871989fbad0>, <networkx.classes.digraph.DiGraph object at 0x7871989f9990>, <networkx.classes.digraph.DiGraph object at 0x787198a68750>, <networkx.classes.digraph.DiGraph object at 0x78719a55e550>, <networkx.classes.digraph.DiGraph object at 0x787198a5ed50>, <networkx.classes.digraph.DiGraph object at 0x787198a6ab10>, <networkx.classes.digraph.DiGraph object at 0x787198d83050>, <networkx.classes.digraph.DiGraph object at 0x7871989fa990>, <networkx.classes.digraph.DiGraph object at 0x787198d81b90>, <networkx.classes.digraph.DiGraph object at 0x787198e368d0>, <networkx.classes.digraph.DiGraph object at 0x787198e35f10>, <networkx.classes.digraph.DiGraph object at 0x787198a63810>, <networkx.classes.digraph.DiGraph object at 0x7871989f9850>, <networkx.classes.digraph.DiGraph object at 0x787198a5f990>, <networkx.classes.digraph.DiGraph  ...

# %%
## 对每个ACFG标记funcion name 和源文件名

# %%
# for name in function_cfgs:
#     used_cfg = function_cfgs[name]
#     for block_addr in used_cfg:
#         block.string = usedc

# %%
# project = angr.Project('./stringtest2', load_options={'auto_load_libs': False})
# cfg = project.analyses.CFGFast()
# function_cfgs = {}

# %%
# for func_addr, func in cfg_2.kb.functions.items():
#     if(func.name == 'main'):
#         print(f"Function at {hex(func_addr)}:")
#         # 遍历基本块
#         for block in func.blocks:
#         # 反汇编基本块
#             block.pp()

# %%
# print(type(cfg))
